# %% [markdown]
# # Demo for the ProblemsSolvers class.
#
# This script is intended to help with debugging problems and solvers.
#
# It create problem-solver groups (using the directory) and runs multiple macroreplications of each problem-solver pair.

# %% [markdown]
# ## Append SimOpt Path
#
# Since the notebook is stored in simopt/notebooks, we need to append the parent simopt directory to the system path to import the necessary modules later on.

# %%
import sys
from pathlib import Path

# Take the current directory, find the parent, and add it to the system path
sys.path.append(str(Path.cwd().parent))

# %% [markdown]
# ## Configuration Parameters
#
# This section defines the core parameters for the demo.
#
# To query model/problem/solver names, run `python scripts/list_directories.py`

# %%
import pickle

# %%
with open("step_testing_exp.pickle", "rb") as f:
    mymetaexperiment=pickle.load(f)

# %%
# Produce basic plots.

from simopt.experiment_base import (
    plot_area_scatterplots,  # noqa: F401
    plot_feasibility_progress,  # noqa: F401
    plot_progress_curves,  # noqa: F401
    plot_solvability_cdfs,  # noqa: F401
    plot_solvability_profiles,  # noqa: F401
    plot_terminal_feasibility,  # noqa: F401
    plot_terminal_progress,  # noqa: F401
    plot_terminal_scatterplots, 
    plot_det_feasibility,
    plot_det_terminal_feasibility,
    PlotType # noqa: F401
)

print("Plotting results...")


def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_progress_curves(
        experiments=mymetaexperiment.experiments[0] + mymetaexperiment.experiments[1] , plot_type=PlotType.ALL, normalize=False
    )
)

print("Plotting complete!")
# Out:
# Plotting results...
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_17-05-14/plots/SOLVER_SET_SAN-3_1_all_prog_curves_unnorm.png')]
# Plotting complete!

# %%
plot_data = plot_data = mymetaexperiment.experiments[9] + mymetaexperiment.experiments[6] +mymetaexperiment.experiments[12]
def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_progress_curves(
        experiments=plot_data, all_in_one = True, plot_type=PlotType.ALL, normalize=False
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_17-05-14/plots/SOLVER_SET_SAN-3_1_all_prog_curves_unnorm (1).png')]
# Plotting complete!

# %%
plot_data = plot_data = mymetaexperiment.experiments[9] + mymetaexperiment.experiments[6] +mymetaexperiment.experiments[12]
def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_terminal_progress(
        experiments=plot_data, normalize = False
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_17-05-14/plots/SOLVER_SET_SAN-3_1_terminal_violin_unnorm.png')]
# Plotting complete!

# %%
plot_data = [mymetaexperiment.experiments[9] , mymetaexperiment.experiments[6] ,mymetaexperiment.experiments[12]]

def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_det_feasibility(
        experiments=plot_data, log_scale = True, score_type = "norm", 
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_17-05-14/plots/SOLVER_SET_SAN-3_1_det_feasibility_progress_unnorm (1) (2) (3) (4).png')]
# Plotting complete!

# %%
def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_det_feasibility(
        experiments=mymetaexperiment.experiments, log_scale = True, log_base = 10
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_16-31-02/plots/SOLVER_SET_SAN-3_det_feasibility_progress_unnorm (1).png')]
# Plotting complete!

# %%
def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_det_feasibility(
        experiments=mymetaexperiment.experiments, log_scale = True, score_type = "objective", obj_const = 1e5
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_16-31-02/plots/SOLVER_SET_SAN-3_det_feasibility_progress_unnorm (1) (2).png')]
# Plotting complete!

# %%
def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_det_feasibility(
        experiments=mymetaexperiment.experiments, log_scale = True, score_type = "objective"
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_16-31-02/plots/SOLVER_SET_SAN-3_det_feasibility_progress_unnorm (1) (2) (3).png')]
# Plotting complete!

# %%
def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_det_feasibility(
        experiments=mymetaexperiment.experiments, log_scale = True, score_type = "norm"
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_16-31-02/plots/SOLVER_SET_SAN-3_det_feasibility_progress_unnorm (1) (2) (3) (4).png')]
# Plotting complete!

# %%
def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_det_terminal_feasibility(
        experiments=mymetaexperiment.experiments[0:5], all_in_one = True, plot_conf_ints = False, score_type = "value"
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_17-05-14/plots/SOLVER_SET_SAN-3_1_det_feasibility_scatter_unnorm.png')]
# Plotting complete!

# %%
def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_det_terminal_feasibility(
        experiments=mymetaexperiment.experiments[6:11], all_in_one = True, plot_conf_ints = False, score_type = "value"
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_17-05-14/plots/SOLVER_SET_SAN-3_1_det_feasibility_scatter_unnorm (1).png')]
# Plotting complete!

# %%
def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_det_terminal_feasibility(
        experiments=mymetaexperiment.experiments[12:], all_in_one = True, plot_conf_ints = False, score_type = "value"
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_17-05-14/plots/SOLVER_SET_SAN-3_1_det_feasibility_scatter_unnorm (1) (2).png')]
# Plotting complete!

# %%
plot_data = plot_data = [mymetaexperiment.experiments[9] , mymetaexperiment.experiments[6] ,mymetaexperiment.experiments[12]]

def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_det_terminal_feasibility(
        experiments=plot_data, all_in_one = True, plot_conf_ints = False, score_type = "value"
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_17-05-14/plots/SOLVER_SET_SAN-3_1_det_feasibility_scatter_unnorm (1) (2) (3) (4).png')]
# Plotting complete!

# %%
def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_det_terminal_feasibility(
        experiments=mymetaexperiment.experiments, all_in_one = True, plot_conf_ints = True
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_16-31-02/plots/SOLVER_SET_SAN-3_det_feasibility_scatter_unnorm (1).png')]
# Plotting complete!

# %%
def _print_path(plot_path: list[Path]) -> None:
    print(f"Plot saved to {plot_path!s}")


_print_path(
    plot_det_terminal_feasibility(
        experiments=mymetaexperiment.experiments, all_in_one = True, plot_conf_ints = True,  plot_zero = False,
    )
)

print("Plotting complete!")
# Out:
# Plot saved to [WindowsPath('C:/Users/nikki/GitHub/simopt/notebooks/experiments/2026-06-19_16-31-02/plots/SOLVER_SET_SAN-3_det_feasibility_scatter_unnorm (1) (2).png')]
# Plotting complete!
