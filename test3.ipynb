# %%
import pickle

from simopt.experiment_base import (
    PlotType,
    plot_feasibility_progress,
    plot_terminal_feasibility,
    plot_terminal_progress,
)

# %%
with open("test-data-2.pkl", "rb") as f:
    e1, e2, e3 = pickle.load(f)

# %%
plot_terminal_progress([e1, e2], PlotType.VIOLIN, normalize=False)
plot_terminal_progress([e1, e2], PlotType.VIOLIN, normalize=True)
plot_terminal_progress([e1, e2], PlotType.VIOLIN, all_in_one=False, normalize=False)
plot_terminal_progress([e1, e2], PlotType.VIOLIN, all_in_one=False, normalize=True)
# Out:
# [PosixPath('/home/derekwang/data/data/Desktop/Important/Research/simopt/experiments/2025-10-22_18-01-59/plots/CSA_SAN-2_terminal_violin.png'),
#  PosixPath('/home/derekwang/data/data/Desktop/Important/Research/simopt/experiments/2025-10-22_18-01-59/plots/CSA-N_SAN-2_terminal_violin.png')]

# %%
plot_terminal_feasibility(
    [[e1], [e2]], PlotType.FEASIBILITY_SCATTER, all_in_one=True, two_sided=True
)
plot_terminal_feasibility(
    [[e1], [e2]], PlotType.FEASIBILITY_SCATTER, all_in_one=False, two_sided=True
)
plot_terminal_feasibility(
    [[e1], [e2]], PlotType.FEASIBILITY_SCATTER, all_in_one=True, two_sided=True
)
plot_terminal_feasibility(
    [[e1], [e2]], PlotType.FEASIBILITY_SCATTER, all_in_one=False, two_sided=True
)
plot_terminal_feasibility(
    [[e1], [e2]],
    PlotType.FEASIBILITY_SCATTER,
    all_in_one=True,
    two_sided=True,
    plot_conf_ints=False,
)
plot_terminal_feasibility(
    [[e1], [e2]],
    PlotType.FEASIBILITY_SCATTER,
    all_in_one=False,
    two_sided=True,
    plot_conf_ints=False,
)
# Out:
# [PosixPath('/home/derekwang/data/data/Desktop/Important/Research/simopt/experiments/2025-10-22_18-01-59/plots/CSA_SAN-2_feasibility_scatter_inf_norm_unnorm (1) (2).png'),
#  PosixPath('/home/derekwang/data/data/Desktop/Important/Research/simopt/experiments/2025-10-22_18-01-59/plots/CSA-N_SAN-2_feasibility_scatter_inf_norm_unnorm (1) (2).png')]

# %%
plot_terminal_feasibility(
    [[e1]], PlotType.FEASIBILITY_VIOLIN, all_in_one=True, two_sided=True
)
plot_terminal_feasibility(
    [[e1], [e2]], PlotType.FEASIBILITY_VIOLIN, all_in_one=False, two_sided=True
)
# Out:
# [PosixPath('/home/derekwang/data/data/Desktop/Important/Research/simopt/experiments/2025-10-22_18-01-59/plots/CSA_SAN-2_feasibility_violin_inf_norm_unnorm.png'),
#  PosixPath('/home/derekwang/data/data/Desktop/Important/Research/simopt/experiments/2025-10-22_18-01-59/plots/CSA-N_SAN-2_feasibility_violin_inf_norm_unnorm.png')]

# %%
plot_feasibility_progress(
    [[e2], [e3]], PlotType.ALL_FEASIBILITY_PROGRESS, print_max_hw=False, two_sided=True
)
plot_feasibility_progress(
    [[e2], [e3]],
    PlotType.ALL_FEASIBILITY_PROGRESS,
    print_max_hw=False,
    two_sided=True,
    all_in_one=False,
)
# Out:
# [PosixPath('/home/derekwang/data/data/Desktop/Important/Research/simopt/experiments/2025-10-22_18-01-59/plots/CSA-N_SAN-2_all_feasibility_progress_inf_norm_unnorm.png'),
#  PosixPath('/home/derekwang/data/data/Desktop/Important/Research/simopt/experiments/2025-10-22_18-01-59/plots/FCSA_SAN-2_all_feasibility_progress_inf_norm_unnorm.png')]

# %%
plot_feasibility_progress(
    [[e2], [e3]],
    PlotType.MEAN_FEASIBILITY_PROGRESS,
    print_max_hw=False,
    two_sided=False,
)
plot_feasibility_progress(
    [[e2], [e3]],
    PlotType.MEAN_FEASIBILITY_PROGRESS,
    print_max_hw=False,
    two_sided=False,
    all_in_one=False,
)
# Out:
# [PosixPath('/home/derekwang/data/data/Desktop/Important/Research/simopt/experiments/2025-10-22_18-01-59/plots/CSA-N_SAN-2_mean_feasibility_progress_inf_norm_unnorm.png'),
#  PosixPath('/home/derekwang/data/data/Desktop/Important/Research/simopt/experiments/2025-10-22_18-01-59/plots/FCSA_SAN-2_mean_feasibility_progress_inf_norm_unnorm.png')]

# %%
plot_feasibility_progress(
    [[e2], [e3]],
    PlotType.QUANTILE_FEASIBILITY_PROGRESS,
    print_max_hw=False,
    two_sided=False,
    beta=0.9,
)
plot_feasibility_progress(
    [[e2], [e3]],
    PlotType.QUANTILE_FEASIBILITY_PROGRESS,
    print_max_hw=False,
    two_sided=False,
    beta=0.9,
    all_in_one=False,
)
# Out:
# [PosixPath('/home/derekwang/data/data/Desktop/Important/Research/simopt/experiments/2025-10-22_18-01-59/plots/CSA-N_SAN-2_0.9_quantile_feasibility_progress_inf_norm_unnorm.png'),
#  PosixPath('/home/derekwang/data/data/Desktop/Important/Research/simopt/experiments/2025-10-22_18-01-59/plots/FCSA_SAN-2_0.9_quantile_feasibility_progress_inf_norm_unnorm.png')]
